# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 1, 21)
y = np.sin(2*x)
plt.plot(x, y, "x")
plt.xlim([0, 1])
plt.show()

# %%
x = np.linspace(0, 1, 21)
y = np.sin(2*x)
plt.plot(x, y, "x")
plt.xlim([-0.02, 1.02])
plt.show()
