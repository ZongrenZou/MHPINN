# %%
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import tensorflow as tf
import time

import models
import flows

# %%
data = sio.loadmat("./data/data_10.mat")
t = data["t"]
u_ref = data["sols"]
f = data["f"]
l = data["l"]

t_train = t[::4]
f_train = f[::4, :2000]
u_ref = u_ref[..., :2000]

# %%
meta = models.Meta(num_tasks=2000, dim=50, name="meta_10")
t0 = time.time()
loss = meta.train(t_train, f_train, niter=50000, ftol=1e-6)
t1 = time.time()
# Out:
# 0 1.0576723 , time:  0.7579987049102783
# 1000 0.0028844045 , time:  2.035001516342163
# 2000 0.0007335255 , time:  2.0760011672973633
# 3000 0.00032272324 , time:  2.020998239517212
# 4000 0.00016436429 , time:  2.0850002765655518
# 5000 0.00014887431 , time:  1.9610040187835693
# 6000 0.00020666834 , time:  1.9799909591674805
# 7000 0.000100507255 , time:  2.0009987354278564
# 8000 8.93045e-05 , time:  2.015000581741333
# 9000 7.960572e-05 , time:  2.0420005321502686
# 10000 0.00012878765 , time:  2.0399997234344482
# 11000 8.1129736e-05 , time:  2.082001209259033
# 12000 7.5401644e-05 , time:  2.064000368118286
# 13000 7.127362e-05 , time:  1.9989979267120361
# 14000 0.00010515009 , time:  2.2209997177124023
# 15000 9.384372e-05 , time:  2.1059987545013428
# 16000 0.00010969923 , time:  2.1230010986328125
# 17000 7.504707e-05 , time:  2.1279993057250977
# 18000 0.00010991702 , time:  2.1260008811950684
# 19000 5.999776e-05 , time:  2.0399999618530273
# 20000 5.971717e-05 , time:  2.156000852584839
# 21000 5.9453498e-05 , time:  2.1940014362335205
# 22000 4.9038274e-05 , time:  2.2180018424987793
# 23000 4.7340818e-05 , time:  2.117001533508301
# 24000 0.0003625834 , time:  2.286000967025757
# 25000 6.828421e-05 , time:  2.1349995136260986
# 26000 3.455151e-05 , time:  2.0970025062561035
# 27000 4.4974546e-05 , time:  2.240001916885376
# 28000 3.1427306e-05 , time:  2.2090001106262207
# 29000 3.578832e-05 , time:  2.216000556945801
# 30000 3.9703318e-05 , time:  2.2326769828796387
# 31000 6.6393695e-05 , time:  2.2521021366119385
# 32000 0.00016024003 , time:  2.159520149230957
# 33000 2.3479763e-05 , time:  2.206998109817505
# 34000 7.456786e-05 , time:  2.1969990730285645
# 35000 6.2065345e-05 , time:  2.1950016021728516
# 36000 1.6218608e-05 , time:  2.189997911453247
# 37000 2.252384e-05 , time:  2.193000316619873
# 38000 1.9651425e-05 , time:  2.1480000019073486
# 39000 1.6643982e-05 , time:  2.192000389099121
# 40000 8.191627e-05 , time:  2.2340002059936523
# 41000 1.4488107e-05 , time:  2.1530044078826904
# 42000 2.4421684e-05 , time:  2.169999837875366
# 43000 3.6290345e-05 , time:  2.1640005111694336
# 44000 1.1587785e-05 , time:  2.1750004291534424
# 45000 2.6644546e-05 , time:  2.1480019092559814
# 46000 7.305275e-05 , time:  2.2940423488616943
# 47000 8.436603e-06 , time:  2.5284199714660645
# 48000 4.1720083e-05 , time:  2.714218854904175
# 49000 0.00019156307 , time:  2.244000196456909

# %%
meta.restore()
print("Elapsed: ", t1 - t0)
t_test = np.linspace(0, 1, 257).reshape([-1, 1])
u_pred = meta.call(
    tf.constant(t_test, tf.float32), meta.heads
).numpy()
i = 2
plt.plot(t_test, u_pred[:, i], '--')
plt.plot(t_test, u_ref[:, 0, i])
plt.show()
# Out:
# Elapsed:  111.32321953773499

# %%
L2 = np.sqrt(np.sum((u_pred - u_ref[:, 0, :])**2, axis=0) / np.sum(u_ref[:, 0, :]**2, axis=0))

# %%
np.mean(L2)
# Out:
# 0.0010266188902945128

# %% [markdown]
# #### Distribution learning

# %%
permutation = list(np.arange(26, 51, 1)) + list(np.arange(0, 26, 1))

nf = flows.MAF(
    dim=51,
    permutation=permutation,
    hidden_layers=[128, 128],
    num_bijectors=10,
    activation=tf.nn.relu,
    
)
heads = meta.heads.numpy().T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2864\2514864145.py in <module>
# ----> 1 permutation = list(np.arange(26, 51, 1)) + list(np.arange(0, 26, 1))
#       2
#       3 nf = flows.MAF(
#       4     dim=51,
#       5     permutation=permutation,
#
# NameError: name 'np' is not defined

# %%
t2 = time.time()
loss = nf.train_batch(tf.constant(heads, tf.float32), nepoch=1000)
t3 = time.time()
# Out:
# 0 -14.432465
# 1 -76.31097
# 2 -88.01495
# 3 -120.742325
# 4 -127.70364
# 5 -131.30998
# 6 -133.19838
# 7 -136.10535
# 8 -136.98404
# 9 -138.64932
# 10 -138.77765
# 11 -140.45166
# 12 -140.81238
# 13 -140.59283
# 14 -141.48727
# 15 -142.79224
# 16 -142.97397
# 17 -142.61353
# 18 -143.70094
# 19 -144.00328
# 20 -143.84741
# 21 -144.7804
# 22 -144.61562
# 23 -144.97829
# 24 -144.88687
# 25 -145.07681
# 26 -145.62148
# 27 -145.67017
# 28 -145.7594
# 29 -146.13382
# 30 -145.87057
# 31 -146.39925
# 32 -146.26657
# 33 -145.84656
# 34 -146.0714
# 35 -146.6708
# 36 -146.41759
# 37 -146.58047
# 38 -145.58278
# 39 -146.6634
# 40 -146.78104
# 41 -147.08736
# 42 -147.31856
# 43 -147.39165
# 44 -147.13687
# 45 -147.37088
# 46 -147.44534
# 47 -147.27487
# 48 -147.48131
# 49 -147.24294
# 50 -147.53487
# 51 -148.17923
# 52 -147.40529
# 53 -147.26646
# 54 -147.79831
# 55 -147.7686
# 56 -147.79579
# 57 -147.56668
# 58 -147.83781
# 59 -147.78862
# 60 -148.12483
# 61 -148.27878
# 62 -148.66338
# 63 -147.9411
# 64 -148.59692
# 65 -148.17009
# 66 -148.18518
# 67 -148.37003
# 68 -148.61188
# 69 -148.43922
# 70 -148.2024
# 71 -148.86588
# 72 -148.71832
# 73 -148.88347
# 74 -148.35228
# 75 -148.77821
# 76 -149.06235
# 77 -148.67865
# 78 -148.68004
# 79 -148.52751
# 80 -147.77382
# 81 -149.21234
# 82 -148.86028
# 381 -163.85886
# 382 -164.79823
# 383 -164.8005
# 384 -164.56557
# 385 -164.85109
# 386 -164.39946
# 387 -165.30946
# 388 -165.10333
# 389 -165.08669
# 390 -165.74245
# 391 -165.11543
# 392 -165.75429
# 393 -165.37875
# 394 -165.77568
# 395 -165.62398
# 396 -166.31319
# 397 -163.3439
# 398 -164.79968
# 399 -164.7583
# 400 -165.9105
# 401 -165.74644
# 402 -165.90083
# 403 -165.01234
# 404 -165.28009
# 405 -164.40219
# 406 -165.66507
# 407 -165.50484
# 408 -166.5582
# 409 -165.81915
# 410 -163.07988
# 411 -165.78621
# 412 -164.96132
# 413 -166.27286
# 414 -165.65256
# 415 -165.95015
# 416 -165.74031
# 417 -166.48265
# 418 -165.94057
# 419 -167.10944
# 420 -165.327
# 421 -166.91138
# 422 -166.05643
# 423 -166.391
# 424 -166.14284
# 425 -165.60396
# 426 -166.19682
# 427 -167.17215
# 428 -167.24341
# 429 -167.23662
# 430 -167.35323
# 431 -164.9208
# 432 -165.49106
# 433 -164.64166
# 434 -165.85776
# 435 -166.40816
# 436 -167.09229
# 437 -167.29485
# 438 -166.87932
# 439 -167.11638
# 440 -167.506
# 441 -167.20715
# 442 -167.1253
# 443 -167.92363
# 444 -167.97577
# 445 -165.77827
# 446 -160.9777
# 447 -165.32169
# 448 -167.04916
# 449 -167.27927
# 450 -167.57085
# 451 -167.50256
# 452 -167.85214
# 453 -167.68024
# 454 -168.77531
# 455 -168.07768
# 456 -167.31485
# 457 -167.69716
# 458 -167.14388
# 459 -167.50674
# 460 -168.12184
# 461 -168.76094
# 462 -168.9694
# 463 -167.66849
# 464 -167.96873
# 465 -168.81084
# 466 -168.51349
# 467 -167.3815
# 468 -168.95065
# 469 -167.99168
# 470 -167.84846
# 471 -167.80534
# 472 -167.58774
# 473 -167.19395
# 474 -168.01816
# 475 -168.37787
# 476 -168.33592
# 477 -168.72023
# 478 -168.43335
# 479 -168.26538
# 480 -167.67241
# 481 -168.22313
# 482 -168.49147
# 483 -168.42941
# 484 -168.87422
# 485 -167.40869
# 486 -168.36769
# 487 -168.2438
# 488 -168.85321
# 489 -169.5729
# 490 -168.27066
# 491 -169.32399
# 492 -168.90807
# 493 -168.63411
# 494 -167.53577
# 495 -168.41304
# 496 -164.34547
# 497 -167.25818
# 498 -168.07538
# 499 -168.60963
# 500 -169.64441
# 501 -168.76819
# 502 -168.7288
# 503 -168.67229
# 504 -168.38185
# 505 -168.90909
# 506 -170.18074
# 507 -168.5604
# 508 -167.91939
# 509 -169.3406
# 510 -168.87631
# 511 -169.31389
# 512 -169.53625
# 513 -169.10791
# 514 -169.34117
# 515 -170.30522
# 516 -168.86594
# 517 -168.58122
# 518 -170.49327
# 519 -170.46646
# 520 -169.45192
# 521 -169.67276
# 522 -170.52649
# 523 -170.42197
# 524 -168.8783
# 525 -170.44919
# 526 -170.215
# 527 -165.73366
# 528 1492659100000.0
# 529 2067306500.0
# 827 -90.05641
# 828 -90.09778
# 829 -90.13989
# 830 -90.182045
# 831 -90.22458
# 832 -90.26717
# 833 -90.30929
# 834 -90.35169
# 835 -90.39531
# 836 -90.43882
# 837 -90.482285
# 838 -90.52634
# 839 -90.57024
# 840 -90.61447
# 841 -90.65828
# 842 -90.70256
# 843 -90.74753
# 844 -90.79199
# 845 -90.83719
# 846 -90.881836
# 847 -90.9272
# 848 -90.97208
# 849 -91.017624
# 850 -91.06275
# 851 -91.10922
# 852 -91.155
# 853 -91.20074
# 854 -91.24699
# 855 -91.29403
# 856 -91.34011
# 857 -91.38711
# 858 -91.43374
# 859 -91.481255
# 860 -91.52915
# 861 -91.57598
# 862 -91.62409
# 863 -91.672844
# 864 -91.72133
# 865 -91.76968
# 866 -91.81833
# 867 -91.86739
# 868 -91.916725
# 869 -91.966484
# 870 -92.01612
# 871 -92.065926
# 872 -92.11676
# 873 -92.16774
# 874 -92.21844
# 875 -92.26983
# 876 -92.32103
# 877 -92.37212
# 878 -92.42491
# 879 -92.478134
# 880 -92.53105
# 881 -92.584656
# 882 -92.638535
# 883 -92.69342
# 884 -92.74805
# 885 -92.8032
# 886 -92.859
# 887 -92.91518
# 888 -92.971985
# 889 -93.029816
# 890 -93.08649
# 891 -93.143875
# 892 -93.201675
# 893 -93.25932
# 894 -93.318344
# 895 -93.37656
# 896 -93.437126
# 897 -93.49689
# 898 -93.55747
# 899 -93.61721
# 900 -93.679474
# 901 -93.74255
# 902 -93.80473
# 903 -93.86918
# 904 -93.93328
# 905 -93.99868
# 906 -94.06393
# 907 -94.12989
# 908 -94.19634
# 909 -94.26433
# 910 -94.33166
# 911 -94.40036
# 912 -94.469635
# 913 -94.54022
# 914 -94.61185
# 915 -94.76675
# 916 -95.018745
# 917 -95.27947
# 918 -95.532425
# 919 -95.75774
# 920 -95.90492
# 921 -96.17818
# 922 -96.41391
# 923 -96.67199
# 924 -96.99262
# 925 -97.39879
# 926 -97.87048
# 927 -98.291374
# 928 -98.579025
# 929 -98.857
# 930 -99.09591
# 931 -99.29494
# 932 -99.46628
# 933 -99.64363
# 934 -99.786964
# 935 -99.94314
# 936 -100.1026
# 937 -100.23726
# 938 -100.37841
# 939 -100.498245
# 940 -100.63843
# 941 -100.73914
# 942 -100.89211
# 943 -101.02628
# 944 -101.1529
# 945 -101.27955
# 946 -101.392525
# 947 -101.52827
# 948 -101.65604
# 949 -101.762054
# 950 -101.90701
# 951 -102.035995
# 952 -102.16524
# 953 -102.28021
# 954 -102.408104
# 955 -102.532486
# 956 -102.65057
# 957 -102.77229
# 958 -102.899
# 959 -103.02408
# 960 -103.14688
# 961 -103.27845
# 962 -103.42407
# 963 -103.5384
# 964 -103.68861
# 965 -103.810326
# 966 -103.96614
# 967 -104.09308
# 968 -104.3512
# 969 -105.09229
# 970 -105.819405
# 971 -106.55986
# 972 -107.21327
# 973 -107.84215
# 974 -108.36823
# 975 -108.77612
# 976 -109.085846
# 977 -109.423355
# 978 -109.714745
# 979 -110.017746
# 980 -110.28134
# 981 -110.525375
# 982 -110.77396
# 983 -110.94464
# 984 -111.19915
# 985 -111.37806
# 986 -111.563995
# 987 -111.72939
# 988 -111.87287
# 989 -112.01652
# 990 -112.16341
# 991 -112.300156
# 992 -112.409195
# 993 -112.552475
# 994 -112.66961
# 995 -112.72742
# 996 -112.88044
# 997 -113.01788
# 998 -113.12103
# 999 -113.23233

# %%
nf.restore()
sample_fn = tf.function(nf.sample)
heads = sample_fn(1000)
t_test = tf.constant(np.linspace(0, 1, 257).reshape([-1, 1]), tf.float32)

u_pred = meta.call(t_test, tf.transpose(heads))
for i in range(1000):
    plt.plot(t_test, u_pred[:, i])
plt.ylim([-1.0, 1])
    
plt.figure()
for i in range(1000):
    plt.plot(t_test, u_ref[:, 0, i])
plt.ylim([-1.0, 1])
# Out:
# (-1.0, 1.0)

# %%
print("Elapsed: ", t1-t0, t3-t2)
print(t1-t0+t3-t2)
# Out:
# Elapsed:  111.32321953773499 179.9585247039795
# 291.2817442417145

# %%
heads = sample_fn(2000)
t_test = tf.constant(np.linspace(0, 1, 257).reshape([-1, 1]), tf.float32)
f_pred = meta.pde(t_test, tf.transpose(heads))
fig = plt.figure(dpi=100)
ax = fig.add_subplot()
for i in range(2000):
    ax.plot(t_test, f_pred[:, i], linestyle="-")
ax.set_ylim([-4, 4])
# ax.set_title("Learned")
# fig.savefig("case_1/case_1_5_learned.png")
# plt.savefig("case_1/learned_distribution.png")
# Out:
# (-4.0, 4.0)

# %%
f_ref = meta.pde(t_test, meta.heads)
fig = plt.figure(dpi=100)
ax = fig.add_subplot()
for i in range(2000):
    ax.plot(t_test, f[:, i], linestyle="-")
ax.set_ylim([-4, 4])
# ax.set_title("Target")
#fig.savefig("case_1/case_1_5_target.png")
# plt.savefig("case_1/target_distribution.png")
# Out:
# (-4.0, 4.0)

# %%
f_pred.shape
# Out:
# TensorShape([257, 2000])

# %%
f_ref.shape
# Out:
# TensorShape([257, 2000])

# %%
import tensorflow_probability as tfp

K = tfp.stats.covariance(tf.transpose(f_pred)) / 256
eigs = tf.linalg.eigvals(K)
eigs = tf.cast(eigs, tf.float32)

K = tfp.stats.covariance(tf.transpose(f[:, :2000])) /256
eigs2 = tf.linalg.eigvals(K)
eigs2 = tf.cast(eigs2, tf.float32)

# %%
plt.plot(eigs[::-1][:20], 'o-', label="learned")
# plt.plot(eigs3[::-1][:20], 's-', label="training")
plt.plot(eigs2[::-1][:20], 's-', label="training")
plt.legend()
plt.title("Top 20 eigenvalues")
# Out:
# Text(0.5, 1.0, 'Top 20 eigenvalues')

# %%
plt.plot(eigs[::-1][:20], 'o-', label="learned")
# plt.plot(eigs3[::-1][:20], 's-', label="training")
plt.plot(eigs2[::-1][:20], 's-', label="training")
plt.legend()
plt.title("Top 20 eigenvalues")
# Out:
# Text(0.5, 1.0, 'Top 20 eigenvalues')
