# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import tensorflow_probability as tfp
import tensorflow as tf
import time
import argparse

import models
import flows

# %%
file_name = "./dataset/data_" + str(int(4)) + ".mat"
data = sio.loadmat(file_name)
t = data["t"]
u_ref = data["sols"]
f = data["f"]
k = data["k"]

# %%
t.shape
# Out:
# (257, 1)

# %%
u_ref.shape
# Out:
# (257, 2, 10000)

# %%
f.shape
# Out:
# (257, 10000)

# %%
t_f_train = t[::8]
f_train = f[::8, :2000]
t_u_train = t[::32]
u_train = u_ref[::32, 0, :2000]
u_exact = u_ref[:, 0, :2000]
k_exact = k[:, :2000]

# %%
k_exact.shape
# Out:
# (1, 2000)

# %%
t_f_train.shape
# Out:
# (33, 1)

# %%
f_train.shape
# Out:
# (33, 2000)

# %%
t_u_train.shape
# Out:
# (9, 1)

# %%
u_train.shape
# Out:
# (9, 2000)

# %%
t_f_train.shape
# Out:
# (33, 1)

# %%
t_u_train.shape
# Out:
# (9, 1)

# %%
plt.plot(t_u_train, u_train)
plt.show()
