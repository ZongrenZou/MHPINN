# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import tensorflow as tf
import time

import models
import flows

import neuraluq as neuq


data = sio.loadmat("./dataset/data_8.mat")
t = data["t"]
u_ref = data["sols"]
f = data["f"]
k = data["k"]

# %%
l = 9999
u_exact = u_ref[:, 0, l:l+1]
f_exact = f[:, l:l+1]
k_exact = k[:, l:l+1]

t_f_train = t[::16]
f_train = f_exact[::16]

np.random.seed(666)
idx = np.random.choice(f_train.shape[0], f_train.shape[0], replace=False)[:5]
f_train = f_train[idx]
t_f_train = t_f_train[idx]

np.random.seed(726991)
# idx_u = np.random.choice(u_exact.shape[0], u_exact.shape[0], replace=False)[:5]
idx_u = [20, 50, 100, 150, 240]
_t_u_train = t[idx_u, :]
_u_train = u_exact[idx_u, :]

# %% [markdown]
# #### Case 1: One data point

# %%
# np.random.seed(3333)
noise_f = 0.05
noise_u = 0.005
u_train = _u_train[:1]
t_u_train = _t_u_train[:1]
f_train = f_train + noise_f * np.random.normal(size=f_train.shape)
u_train = u_train + noise_u * np.random.normal(size=u_train.shape)

# %%
plt.plot(t_f_train, f_train, 'o')
plt.plot(t, f_exact)
plt.figure()
plt.plot(t_u_train, u_train, "o")
plt.plot(t, u_exact)

# %%
#### Load meta and nf
# meta = models.MHPINN(num_tasks=2000, dim=50, name="mhpinn")
meta = models.MHPINN(num_tasks=2000, dim=50, name="meta_KL_8")
meta.restore()

permutation = list(np.arange(26, 52, 1)) + list(np.arange(0, 26, 1))
nf = flows.MAF(
    dim=52,
    permutation=permutation,
    hidden_layers=[100, 100],
    num_bijectors=10,
    activation=tf.nn.relu,
    name="maf_KL_8",
)
nf.restore()

# %%
import hmc

# %%
def pde_fn(t, u, log_k):
    u_t = tf.gradients(u, t)[0]
    u_tt = tf.gradients(u_t, t)[0]
    k = tf.math.exp(log_k)
    f_pred = u_tt + k * tf.math.sin(u)
    return f_pred

# %%
model = hmc.PI_Bayesian(
    t_u=t_u_train, 
    u=u_train, 
    t_f=t_f_train, 
    f=f_train, 
    pde_fn=pde_fn, 
    meta=meta, 
    flow=nf,
    noise_u=noise_u,
    noise_f=noise_f,
)
# Out:
# 2025-03-16 11:53:00.123612: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %%
log_posterior = model.build_posterior()
hmc_kernel = hmc.AdaptiveHMC(
    target_log_prob_fn=log_posterior,
    init_state=tf.zeros_like(model.initial_values),
    # init_state=model.initial_values,
    num_results=1000,
    num_burnin=1000,
    num_leapfrog_steps=30,
    step_size=0.01,
)

# %%
samples, results = hmc_kernel.run_chain()
# Out:
# (1, 52) (1, 51) (1, 1)
# (1, 1) (5, 1)
# (5, 1)
# /opt/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/mcmc/sample.py:339: UserWarning: Tracing all kernel results by default is deprecated. Set the `trace_fn` argument to None (the future default value) or an explicit callback that traces the values you are interested in.
#   warnings.warn('Tracing all kernel results by default is deprecated. Set '
# (1, 52) (1, 51) (1, 1)
# (1, 1) (5, 1)
# (5, 1)

# %%
print('Accepted rate: ', np.mean(results.inner_results.is_accepted.numpy()))
# Out:
# Accepted rate:  0.731

# %%
plt.figure(dpi=100)
plt.hist(tf.math.exp(samples[:, 0, -1]).numpy(), density=True, label="posterior", bins=10, alpha=0.3)
plt.hist(tf.math.exp(nf.sample(1000)[:, -1]).numpy().flatten(), density=True, label="prior", bins=10, alpha=0.3)
plt.legend()
plt.savefig("histogram2.png")
plt.show()

# %%
k_posterior = tf.math.exp(samples[:, 0, -1])
k_prior = tf.math.exp(nf.sample(1000)[:, -1]).numpy().flatten()

# %%
k_exact
# Out:
# array([[2.36091292]])

# %%
print(np.mean(tf.math.exp(samples[:, 0, -1]).numpy()))
print(np.std(tf.math.exp(samples[:, 0, -1]).numpy()))
# Out:
# 2.497834
# 0.4320397

# %%
t_test = tf.constant(t, tf.float32)
u_pred = model.meta.call(t_test, tf.transpose(samples[:, 0, :-1])).numpy()
mu_u = np.mean(u_pred, axis=-1)
std_u = np.std(u_pred, axis=-1)

f_pred = meta.pde(t_test, tf.transpose(samples[:, 0, :-1]), samples[:, 0, -1])
mu_f = np.mean(f_pred, axis=-1)
std_f = np.std(f_pred, axis=-1)

# %%
fig = plt.figure(dpi=100)
ax = fig.add_subplot()
ax.fill_between(t_test.numpy().flatten(), (mu_u+2*std_u), (mu_u-2*std_u), alpha=0.3, label="2 std")
ax.scatter(t_u_train, u_train, s=5, color="blue", marker="o", facecolor="none", linewidths=8, label="measurements")
ax.plot(t, u_exact, color="black", linestyle="-", linewidth=2, label="reference")
ax.plot(t, mu_u, color="red", linestyle="--", linewidth=2, label="mean")
ax.legend()
ax.set_ylabel("$u$")
ax.set_xlabel("$t$")
ax.set_ylim([-0.03, 0.11])
plt.show()
# plt.savefig("u_uq.png")

# %%
fig = plt.figure(dpi=100)
ax = fig.add_subplot()
ax.fill_between(t_test.numpy().flatten(), (mu_f+2*std_f), (mu_f-2*std_f), alpha=0.3, label="2 std")
ax.scatter(t_f_train, f_train, s=5, color="blue", marker="o", facecolor="none", linewidths=8, label="measurements")
ax.plot(t, f_exact, color="black", linestyle="-", linewidth=2, label="reference")
ax.plot(t, mu_f, color="red", linestyle="--", linewidth=2, label="mean")
# ax.legend()
ax.set_ylabel("$f$")
ax.set_xlabel("$t$")
# ax.set_ylim([-1.7, 1.2])
# plt.savefig("f_uq.png")
plt.show()

# %% [markdown]
# #### Case 2: Two data points

# %%
# np.random.seed(3333)
noise_f = 0.05
noise_u = 0.005
u_train = _u_train[:2]
t_u_train = _t_u_train[:2]
f_train = f_train + noise_f * np.random.normal(size=f_train.shape)
u_train = u_train + noise_u * np.random.normal(size=u_train.shape)

# %%
#### Load meta and nf
# meta = models.MHPINN(num_tasks=2000, dim=50, name="mhpinn")
meta = models.MHPINN(num_tasks=2000, dim=50, name="meta_KL_8")
meta.restore()

permutation = list(np.arange(26, 52, 1)) + list(np.arange(0, 26, 1))
nf = flows.MAF(
    dim=52,
    permutation=permutation,
    hidden_layers=[100, 100],
    num_bijectors=10,
    activation=tf.nn.relu,
    name="maf_KL_8",
)
nf.restore()

# %%
def pde_fn(t, u, log_k):
    u_t = tf.gradients(u, t)[0]
    u_tt = tf.gradients(u_t, t)[0]
    k = tf.math.exp(log_k)
    f_pred = u_tt + k * tf.math.sin(u)
    return f_pred

# %%
model = hmc.PI_Bayesian(
    t_u=t_u_train, 
    u=u_train, 
    t_f=t_f_train, 
    f=f_train, 
    pde_fn=pde_fn, 
    meta=meta, 
    flow=nf,
    noise_u=noise_u,
    noise_f=noise_f,
)

# %%
log_posterior = model.build_posterior()
hmc_kernel = hmc.AdaptiveHMC(
    target_log_prob_fn=log_posterior,
    init_state=tf.zeros_like(model.initial_values),
    # init_state=model.initial_values,
    num_results=1000,
    num_burnin=1000,
    num_leapfrog_steps=30,
    step_size=0.01,
)
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).opt.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).opt.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).opt.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).opt.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).opt.learning_rate

# %%
samples, results = hmc_kernel.run_chain()
# Out:
# (1, 52) (1, 51) (1, 1)
# (2, 1) (5, 1)
# (5, 1)
# /opt/anaconda3/envs/tf2/lib/python3.8/site-packages/tensorflow_probability/python/mcmc/sample.py:339: UserWarning: Tracing all kernel results by default is deprecated. Set the `trace_fn` argument to None (the future default value) or an explicit callback that traces the values you are interested in.
#   warnings.warn('Tracing all kernel results by default is deprecated. Set '
# (1, 52) (1, 51) (1, 1)
# (2, 1) (5, 1)
# (5, 1)

# %%
print('Accepted rate: ', np.mean(results.inner_results.is_accepted.numpy()))
# Out:
# Accepted rate:  0.677

# %%
k_posterior = tf.math.exp(samples[:, 0, -1])
k_prior = tf.math.exp(nf.sample(1000)[:, -1]).numpy().flatten()

# %%
k_exact
# Out:
# array([[2.36091292]])

# %%
print(np.mean(tf.math.exp(samples[:, 0, -1]).numpy()))
print(np.std(tf.math.exp(samples[:, 0, -1]).numpy()))
# Out:
# 3.4198794
# 0.47396457

# %%
t_test = tf.constant(t, tf.float32)
u_pred = model.meta.call(t_test, tf.transpose(samples[:, 0, :-1])).numpy()
mu_u = np.mean(u_pred, axis=-1)
std_u = np.std(u_pred, axis=-1)

f_pred = meta.pde(t_test, tf.transpose(samples[:, 0, :-1]), samples[:, 0, -1])
mu_f = np.mean(f_pred, axis=-1)
std_f = np.std(f_pred, axis=-1)

# %%
noise_f
# Out:
# 0.05

# %%
fig = plt.figure(dpi=100)
ax = fig.add_subplot()
ax.fill_between(t_test.numpy().flatten(), (mu_u+2*std_u), (mu_u-2*std_u), alpha=0.3, label="2 std")
ax.scatter(t_u_train, u_train, s=5, color="blue", marker="o", facecolor="none", linewidths=8, label="measurements")
ax.plot(t, u_exact, color="black", linestyle="-", linewidth=2, label="reference")
ax.plot(t, mu_u, color="red", linestyle="--", linewidth=2, label="mean")
ax.legend()
ax.set_ylabel("$u$")
ax.set_xlabel("$t$")
ax.set_ylim([-0.03, 0.11])
plt.show()
# plt.savefig("u_uq.png")

# %%
fig = plt.figure(dpi=100)
ax = fig.add_subplot()
ax.fill_between(t_test.numpy().flatten(), (mu_f+2*std_f), (mu_f-2*std_f), alpha=0.3, label="2 std")
ax.scatter(t_f_train, f_train, s=5, color="blue", marker="o", facecolor="none", linewidths=8, label="measurements")
ax.plot(t, f_exact, color="black", linestyle="-", linewidth=2, label="reference")
ax.plot(t, mu_f, color="red", linestyle="--", linewidth=2, label="mean")
# ax.legend()
ax.set_ylabel("$f$")
ax.set_xlabel("$t$")
# ax.set_ylim([-1.7, 1.2])
# plt.savefig("f_uq.png")
plt.show()
