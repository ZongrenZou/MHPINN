# %%
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt

import dataset

# %% [markdown]
# #### Case 1-2

# %%
# xx1, yy1, xx2, yy2, w1, w2, A, k = dataset.generate_data(N=4000, M1=32, M2=64)
# sio.savemat(
#     "case3.mat",
#     {
#         "x1": xx1,
#         "y1": yy1,
#         "x2": xx2,
#         "y2": yy2,
#         "w1": w1,
#         "w2": w2,
#         "A": A,
#         "k": k
#     }
# )

# %% [markdown]
# #### Case 3

# %%
xx2.shape
# Out:
# (2003, 64)

# %%
xx1.shape
# Out:
# (1997, 32)

# %%
xx1.shape, xx2.shape
# Out:
# ((1997, 32), (2003, 64))

# %%
plt.plot(xx1[0, :], yy1[11, :], '.')
plt.plot(xx2[0, :], yy2[10, :], '+')
print(w1[11], w2[10])
# Out:
# [8.18237315] [11.08432739]

# %%
yy2.shape
# Out:
# (2047, 64)

# %%
for i in range(500):
    plt.plot(xx1[0, :], yy1[i, :])

# %%
for i in range(500):
    plt.plot(xx2[0, :], yy2[i, :])

# %%
plt.hist(np.concatenate([w1, w2], axis=0), bins=30)
plt.show()

# %%
w1.shape, w2.shape
# Out:
# ((2000, 1), (2000, 1))

# %%
5*np.pi
# Out:
# 15.707963267948966

# %%
np.max(w2)
# Out:
# 12.5663109175363

# %%
4*np.pi
# Out:
# 12.566370614359172
